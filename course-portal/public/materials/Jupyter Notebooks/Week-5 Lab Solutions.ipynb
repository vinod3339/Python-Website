# %% [markdown]
# Python Lab: Strings

# %% [markdown]
# Basics

# %%
# Take a string input from the user and print its length.
user_string = input("Enter a string: ")
print("Length of the string:", len(user_string))
# Out:
# Length of the string: 5

# %%
# Reverse a given string (without using slicing, then with slicing)

user_string = input("Enter a string: ")
reversed_string = ""

for char in user_string:
    reversed_string = char + reversed_string

print("Reversed string (without slicing):", reversed_string)
print("Reversed string (with slicing):", user_string[::-1])
# Out:
# Reversed string (without slicing): nohtyp
# Reversed string (with slicing): nohtyp

# %%
# Check if a given string is a palindrome.

user_string = input("Enter a string: ")

if user_string == user_string[::-1]:
    print("The string is a palindrome.")
else:   
    print("The string is not a palindrome.")
# Out:
# The string is a palindrome.

# %%
# Check if a given string is a palindrome(without using slicing).

user_string = input("Enter a string: ")

is_palindrome = True

for i in range(len(user_string) // 2):
    if user_string[i] != user_string[len(user_string) - 1 - i]:
        is_palindrome = False
        break

if is_palindrome:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# The string is not a palindrome.

# %%
#Convert a string to uppercase and lowercase.

user_string = input("Enter a string: ")
uppercase_string = user_string.upper()
lowercase_string = user_string.lower()

print("Uppercase string:", uppercase_string)
print("Lowercase string:", lowercase_string)
# Out:
# Uppercase string: VINOD
# Lowercase string: vinod

# %%
#Count the number of vowels, consonants, digits, and spaces in a string.

user_string = input("Enter a string: ")
vowels = 0
consonants = 0
digits = 0
spaces = 0

for char in user_string:
    if char.isalpha():
        if char.lower() in 'aeiou':
            vowels += 1
        else:
            consonants += 1
    elif char.isdigit():
        digits += 1
    elif char.isspace():
        spaces += 1

print("Number of vowels:", vowels)
print("Number of consonants:", consonants)
print("Number of digits:", digits)
print("Number of spaces:", spaces)
# Out:
# Number of vowels: 4
# Number of consonants: 6
# Number of digits: 0
# Number of spaces: 0

# %% [markdown]
# Manipulation

# %%
# Count the occurrences of a specific character in a string

def count_character(string, character):
    count = 0
    for char in string:
        if char == character:
            count += 1
    return count    

user_string = input("Enter a string: ")
character = input("Enter a character to count: ")
result = count_character(user_string, character)
print(f"The character '{character}' appears {result} times in the string.")
# Out:
# The character 'a' appears 2 times in the string.

# %%
# Remove all whitespace from a string.
user_string = input("Enter a string: ")
string_without_whitespace = user_string.replace(" ", "")
print("String without whitespace:", string_without_whitespace)
# Out:
# String without whitespace: vinod

# %%
# Replace all occurrences of a character/word with another.
user_string = input("Enter a string: ")
old_character = input("Enter the character/word to replace: ")
new_character = input("Enter the new character/word: ")
modified_string = user_string.replace(old_character, new_character)
print("Modified string:", modified_string)
# Out:
# Modified string: pytnon

# %%
# Concatenate two strings without using the + operator.
string1 = input("Enter the first string: ")
string2 = input("Enter the second string: ")

concatenated_string = string1 + string2
print("Concatenated string:", concatenated_string)
# Out:
# Concatenated string: vinodkumar

# %%
# Swap the case of each character in a string (upper → lower and vice versa).
user_string = input("Enter a string: ")
swapped_case_string = user_string.swapcase()
print("String with swapped case:", swapped_case_string)
# Out:
# String with swapped case: VINOD

# %% [markdown]
# Slicing & Indexing

# %%
#Extract the first and last characters of a string.
user_string = input("Enter a string: ")
first_character = user_string[0]
last_character = user_string[-1]
print("First character:", first_character)
print("Last character:", last_character)
# Out:
# First character: v
# Last character: d

# %%
# Print every second character of a string.
user_string = input("Enter a string: ")
second_characters = user_string[1::2]
print("Every second character:", second_characters)
# Out:
# Every second character: iokmr

# %%
# Check if a substring exists within a string.
user_string = input("Enter a string: ")
substring = input("Enter a substring to check: ")
if substring in user_string:
    print(f"The substring '{substring}' exists in the string.")
else:
    print(f"The substring '{substring}' does not exist in the string.")
# Out:
# The substring 'vinod' exists in the string.

# %%
# Find the index of the first and last occurrence of a character.
user_string = input("Enter a string: ")
character = input("Enter a character to find: ")
first_index = user_string.find(character)
last_index = user_string.rfind(character)
if first_index != -1:
    print(f"First occurrence of '{character}': Index {first_index}")
else:
    print(f"Character '{character}' not found in the string.")

if last_index != -1:
    print(f"Last occurrence of '{character}': Index {last_index}")
else:
    print(f"Character '{character}' not found in the string.")
# Out:
# First occurrence of 'j': Index 1
# Last occurrence of 'j': Index 1

# %% [markdown]
# Words & Sentences

# %%
# Count the number of words in a sentence
user_string = input("Enter a sentence: ")
word_count = len(user_string.split())
print("Number of words in the sentence:", word_count)
# Out:
# Number of words in the sentence: 2

# %%
# Find the longest word in a sentence
user_string = input("Enter a sentence: ")
words = user_string.split()
longest_word = max(words, key=len)
print("Longest word in the sentence:", longest_word)
# Out:
# Longest word in the sentence: kumaar

# %%
# Reverse the order of words in a sentence (without reversing each word).
user_string = input("Enter a sentence: ")
words = user_string.split() 
reversed_words = words[::-1]
print("Reversed order of words in the sentence:", ' '.join(reversed_words))
# Out:
# Reversed order of words in the sentence: kumar vinod

# %%
# Capitalize the first letter of every word (Title Case), without using .title().
user_string = input("Enter a sentence: ")
words = user_string.split()
capitalized_words = [word.capitalize() for word in words]
print("Title case of the sentence:", ' '.join(capitalized_words))
# Out:
# Title case of the sentence: Vinod Kumar

# %%
# Check if two strings are anagrams of each other
string1 = input("Enter the first string: ")
string2 = input("Enter the second string: ")

if sorted(string1.replace(" ", "").lower()) == sorted(string2.replace(" ", "").lower()):
    print("The two strings are anagrams of each other.")
else:
    print("The two strings are not anagrams of each other.")
# Out:
# The two strings are anagrams of each other.

# %% [markdown]
# Advanced

# %%
# Remove duplicate characters from a string.
user_string = input("Enter a string: ")
unique_characters = ""
for char in user_string:
    if char not in unique_characters:
        unique_characters += char
print("String with duplicate characters removed:", unique_characters)
# Out:
# String with duplicate characters removed: vinodk

# %%
# Check if a string contains only digits, only alphabets, or is alphanumeric.
user_string = input("Enter a string: ")

if user_string.isdigit():
    print("The string contains only digits.")
elif user_string.isalpha():
    print("The string contains only alphabets.")
elif user_string.isalnum():
    print("The string is alphanumeric.")
else:
    print("The string contains characters other than digits, alphabets, or both.")

# %%
# Find all the duplicate characters in a string and their counts.
user_string = input("Enter a string: ")
duplicate_chars = {}

for char in user_string:
    duplicate_chars[char] = duplicate_chars.get(char, 0) + 1

# Filter out characters that appear only once
duplicate_chars = {char: count for char, count in duplicate_chars.items() if count > 1}

print("Duplicate characters and their counts:")
for char, count in duplicate_chars.items():
    print(f"'{char}': {count}")
# Out:
# Duplicate characters and their counts:
# 'd': 3
# 'a': 2

# %%
# Convert a string into a list of characters and back into a string.
user_string = input("Enter a string: ")
char_list = list(user_string)
new_string = "".join(char_list)
print("List of characters:", char_list)
print("String reconstructed from list of characters:", new_string)
# Out:
# List of characters: ['v', 'i', 'n', 'o', 'd']
# String reconstructed from list of characters: vinod

# %%
# Write a program to check if a string is a valid identifier (like a Python variable name).
user_string = input("Enter a string: ")

if user_string.isidentifier():
    print("The string is a valid identifier.")
else:
    print("The string is not a valid identifier.")
# Out:
# The string is not a valid identifier.
